# %%
import time

# %%
import mysql.connector
import pandas as pd
import inspect
import datetime
import os

# %%
def get_file_size(file_path):
    size = os.path.getsize(file_path)
    return size

# %% [markdown]
# Database connections

# %%
def mycon(db_name):
    try:
        mydb = mysql.connector.connect(host="192.168.45.29", user="bida_analysis_view", password="bida2022$",
                                       database="amrit_analysis", auth_plugin="mysql_native_password")
        return mydb
    except Exception as e:
        print(e)
        print("An error has been occured")

# %%
def create_parquet_file(file_name):
    start_time = datetime.datetime.now()
    print_process_time(start_time, inspect.stack()[0][3])
    #mydb = mycon("amrit_analysis")

    # mycursor = mydb.cursor()
    # query4 = '''SELECT * FROM amrit_analysis.all_res_of_obh_t_call_raw_data_datewise'''
    # query2 = '''
    # select state,rec_created_date,male as "male",female as "female",
    # transgender,not_disclosed,lt_1_year, 1_to_5_years, 6_to_10_years,
    # 11_to_20_years, 21_to_30_years, 31_to_40_years, 41_to_50_years,
    # 51_to_60_years, gt_60_years
    # from amrit_analysis.all_res_of_age_gen_t_bancall_count_datewise;
    # '''
    # mycursor.execute(query4)
    # df = pd.DataFrame(mycursor.fetchall())
    # df.columns = mycursor.column_names
    # #print(mycursor.column_names)
    # print(df.columns)
    # df.drop_duplicates(inplace=True)
    # print(df.shape)
    print_process_time(start_time, inspect.stack()[0][3])
    #df.to_parquet(f'{file_name}',engine='auto', compression='gzip', index=None)
    read_parquet_file(file_name)
    print_process_time(start_time, inspect.stack()[0][3])

# %%
def read_parquet_file(file_name):
    start_time = datetime.datetime.now()
    convert_bytes(get_file_size(file_name), 'MB')
    df = pd.read_parquet(f'{file_name}', engine='auto')
    print_process_time(start_time, inspect.stack()[0][3])
    print(df.columns)
   # print(df.describe())
    x=df.head()
    #print(f"{list(df.shape)}")
    #print_process_time(start_time, inspect.stack()[0][3])
    # print(df[df['state'] == 'BH'].head())
    # print(df[df['state'] == 'JH'].head())
    # print(df[df['state'] == 'HP'].head())
    # print(df[df['state'] == 'AS'].head())

# %%
def convert_bytes(size, unit=None):
    if unit == "KB":
        print('File size: ' + str(round(size / 1024, 3)) + ' Kilobytes')
    elif unit == "MB":
        print('File size: ' + str(round(size / (1024 * 1024), 3)) + ' Megabytes')
    elif unit == "GB":
        print('File size: ' + str(round(size / (1024 * 1024 * 1024), 3)) + ' Gigabytes')
    else:
        print('File size: ' + str(size) + ' bytes')
    return 0

# %%
def print_process_time(start_time=0,func_name=""):
    print(f"{datetime.datetime.now()-start_time} taken by {func_name}")

# %%
file_name = "D:\\104 Data Analysis\\all_state_t_call_raw_data.parquet.gzip"
create_parquet_file(file_name)
# Out:
# 0:00:00.016913 taken by create_parquet_file
# 0:00:00.030875 taken by create_parquet_file
# File size: 99.733 Megabytes
# 0:00:11.723728 taken by read_parquet_file
# Index(['state', 'date_created', 'ben_call_id', 'call_id', 'beneficiary_reg_id',
#        'beneficiary_dist_name', 'beneficiary_gender', 'disease_summary',
#        'algorithm', 'call_start_time', 'call_end_time', 'received_role_name',
#        'call_type', 'date_created_fulltime', 'da_created_on_timestamp',
#        'da_is_match', 'da_is_match_date', 'da_is_verified',
#        'da_is_verified_date', 'da_is_verified_count'],
#       dtype='object')
# 0:00:12.433018 taken by create_parquet_file

# %%
df = pd.read_parquet(f'{file_name}', engine='auto')
df
# Out:
#         state date_created  ben_call_id                call_id  \
# 0          BH   2019-10-21           18  1571661343.7900000000
# 1          BH   2019-10-21           18  1571661343.7900000000
# 2          BH   2019-10-21           20  1571661673.8400000000
# 3          BH   2019-10-21           22  1571661809.8800000000
# 4          BH   2019-10-21           23  1571661851.9000000000
# ...       ...          ...          ...                    ...
# 4229268    AS   2022-08-31      6752877  1661930278.3962000000
# 4229269    AS   2022-08-31      6752886  1661930335.3986000000
# 4229270    AS   2022-08-31      6752887  1661930345.3988000000
# 4229271    AS   2022-08-31      6752890  1661930353.3995000000
# 4229272    AS   2022-08-31      6752896  1661930353.3995000000
#
#          beneficiary_reg_id beneficiary_dist_name beneficiary_gender  \
# 0                       2.0                 Patna               Male
# 1                       2.0                 Patna               Male
# 2                       4.0            Aurangabad               Male
# 3                       3.0            Aurangabad               Male
# 4                       4.0            Aurangabad               Male
# ...                     ...                   ...                ...
# 4229268           6874655.0                Kamrup             Female
# 4229269           6875203.0         Karbi Anglong               Male
# 4229270           6880238.0                Cachar             Female
# 4229271           7106721.0          Kamrup Metro             Female
# 4229272           7106721.0          Kamrup Metro             Female
#
#                          disease_summary algorithm     call_start_time  \
# 0                                   None      None 2019-10-21 18:10:01
# 1                                   None      None 2019-10-21 18:10:01
# 2                                   None      None 2019-10-21 18:12:41
# 3                                   None      None 2019-10-21 18:13:28
# 4                                   None      None 2019-10-21 18:13:56
# ...                                  ...       ...                 ...
# 4229268                             None      None 2022-08-31 12:48:39
# 4229269                             None      None 2022-08-31 12:49:37
# 4229270                             None      None 2022-08-31 12:49:46
# 4229271                     MOUTH ULCERS      None 2022-08-31 12:49:54
# 4229272  Tongue inflammation (Glossitis)      None 2022-08-31 12:51:19
#
#                call_end_time received_role_name            call_type  \
# 0                       None                HAO  Counselling Officer
# 1                       None                HAO  Counselling Officer
# 2                       None                HAO  Counselling Officer
# 3                       None                HAO  Counselling Officer
# 4                       None                HAO  Counselling Officer
# ...                      ...                ...                  ...
# 4229268  2022-08-31 12:49:40         HYBRID HAO                Intro
# 4229269  2022-08-31 12:50:31         HYBRID HAO                Intro
# 4229270  2022-08-31 12:50:47         HYBRID HAO     Information Call
# 4229271  2022-08-31 12:51:19         HYBRID HAO      Medical Officer
# 4229272  2022-08-31 12:54:45                 MO   Health Advice Call
#
#         date_created_fulltime da_created_on_timestamp  da_is_match  \
# 0         2019-10-21 18:05:56     2022-08-16 21:20:05            0
# 1         2019-10-21 18:05:56     2022-08-16 21:34:37            0
# 2         2019-10-21 18:11:40     2022-08-16 21:34:53            0
# 3         2019-10-21 18:13:09     2022-08-16 21:34:53            0
# 4         2019-10-21 18:13:37     2022-08-16 21:34:53            0
# ...                       ...                     ...          ...
# 4229268   2022-08-31 12:48:38     2022-08-31 12:51:21            0
# 4229269   2022-08-31 12:49:36     2022-08-31 12:51:21            0
# 4229270   2022-08-31 12:49:45     2022-08-31 12:51:21            0
# 4229271   2022-08-31 12:49:53     2022-08-31 12:51:21            0
# 4229272   2022-08-31 12:51:19     2022-08-31 12:54:48            0
#
#          da_is_match_date  da_is_verified  da_is_verified_date  \
# 0                       0               0                    0
# 1                       0               0                    0
# 2                       0               0                    0
# 3                       0               0                    0
# 4                       0               0                    0
# ...                   ...             ...                  ...
# 4229268                 0               0                    0
# 4229269                 0               0                    0
# 4229270                 0               0                    0
# 4229271                 0               0                    0
# 4229272                 0               0                    0
#
#          da_is_verified_count
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# ...                       ...
# 4229268                     0
# 4229269                     0
# 4229270                     0
# 4229271                     0
# 4229272                     0
#
# [4229273 rows x 20 columns]

# %%
df.shape
# Out:
# (4229273, 20)

# %%
file_name
# Out:
# 'D:\\104 Data Analysis\\all_state_t_call_raw_data.parquet.gzip'

# %%
f = pd.DataFrame(data={'col_1': [2, 3], 'col_2': [4, 5]})
f.to_parquet('df.parquet.gzip', compression='gzip')
d.read_parquet('df.parquet.gzip')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SANDEE~1\AppData\Local\Temp/ipykernel_10848/1041157455.py in <module>
#       1 f = pd.DataFrame(data={'col_1': [2, 3], 'col_2': [4, 5]})
#       2 f.to_parquet('df.parquet.gzip', compression='gzip')
# ----> 3 d.read_parquet('df.parquet.gzip')
#
# NameError: name 'd' is not defined
